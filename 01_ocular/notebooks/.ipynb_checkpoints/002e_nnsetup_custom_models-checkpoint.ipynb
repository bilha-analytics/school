# %% [markdown]
# # Custom Models & Sklearn+PyTorch

# %%
# %run "002d_nnsetup_class_objects.ipynb"

# %%
OUTPUTDIR = "/mnt/externz/zRepoz/003_school/scinet_fmri_tuts/01.ocular/eda_fundus_outputs/output"
FMAPS_OUTPUTDIR = "/mnt/externz/zRepoz/003_school/scinet_fmri_tuts/01.ocular/eda_fundus_outputs/fmaps"
## 1. Reset Output Dir
def purge_dir(dpath):    
    for f in glob.glob(f'{dpath}/*.png'):
        os.remove(f)         
purge_dir(OUTPUTDIR)
print('output dir reset')
## 2. Setup dataset 
NUM_CLASSES = 3
CLASS_LABELZ = ['UnDef', 'Normal', 'Sick']

idf3 = PdDataStats()
idf3.load_stare_fundus_dir( )

t = YLabelzFundusTransformer()
idf3.dframe = t.transform(idf3.dframe)

idf3.summarize()
idf3.visualize('dclass', plt_type='barh', countz=True, stacked=False)
# Out:
# output dir reset
# Loading fundus dir: /mnt/externz/zRepoz/datasets/fundus/stare
# one-hot shape:  (15, 15)
#          fname                                              fpath  \
# count      397                                                397
# unique     397                                                397
# top     im0323  /mnt/externz/zRepoz/datasets/fundus/stare/im00...
# freq         1                                                  1
# mean       NaN                                                NaN
# std        NaN                                                NaN
# min        NaN                                                NaN
# 25%        NaN                                                NaN
# 50%        NaN                                                NaN
# 75%        NaN                                                NaN
# max        NaN                                                NaN
#
#                ishape        imin        imax       imean        istd  \
# count             397  397.000000  397.000000  397.000000  397.000000
# unique              1         NaN         NaN         NaN         NaN
# top     (605, 700, 3)         NaN         NaN         NaN         NaN
# freq              397         NaN         NaN         NaN         NaN
# mean              NaN    0.065491  253.967254   83.071825   73.856816
# std               NaN    0.247703    6.358915   15.154158   13.368342
# min               NaN    0.000000  179.000000   49.365399   31.962128
# 25%               NaN    0.000000  255.000000   72.793943   66.022203
# 50%               NaN    0.000000  255.000000   81.432149   76.270379
# 75%               NaN    0.000000  255.000000   92.292583   83.227167
# max               NaN    1.000000  255.000000  178.768331  105.020058
#
#        dcodez_id dcodez_short        dcodez_desc  ...    BDR-NPDR         PDR  \
# count        397          397                397  ...  397.000000  397.000000
# unique        48           48                 48  ...         NaN         NaN
# top           14        UNDEF  Unknown Diagnosis  ...         NaN         NaN
# freq          90           90                 90  ...         NaN         NaN
# mean         NaN          NaN                NaN  ...    0.176322    0.057935
# std          NaN          NaN                NaN  ...    0.381575    0.233914
# min          NaN          NaN                NaN  ...    0.000000    0.000000
# 25%          NaN          NaN                NaN  ...    0.000000    0.000000
# 50%          NaN          NaN                NaN  ...    0.000000    0.000000
# 75%          NaN          NaN                NaN  ...    0.000000    0.000000
# max          NaN          NaN                NaN  ...    1.000000    1.000000
#
#                ASR         HTR       Coats          MA         CNV  \
# count   397.000000  397.000000  397.000000  397.000000  397.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.083123    0.090680    0.035264    0.020151    0.153652
# std       0.276417    0.287516    0.184680    0.140694    0.361070
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       0.000000    0.000000    0.000000    0.000000    0.000000
# 50%       0.000000    0.000000    0.000000    0.000000    0.000000
# 75%       0.000000    0.000000    0.000000    0.000000    0.000000
# max       1.000000    1.000000    1.000000    1.000000    1.000000
#
#              UNDEF  dclass    dclass_v
# count   397.000000     397  397.000000
# unique         NaN       3         NaN
# top            NaN    Sick         NaN
# freq           NaN     202         NaN
# mean      0.400504     NaN    1.115869
# std       0.495739     NaN    0.943706
# min       0.000000     NaN    0.000000
# 25%       0.000000     NaN    0.000000
# 50%       0.000000     NaN    2.000000
# 75%       1.000000     NaN    2.000000
# max       2.000000     NaN    2.000000
#
# [11 rows x 28 columns]

# %%
#idf3.dframe.head(3).T

# %%
nmax = 30 

#dftmp = idf3.dframe.sample(nmax) 

dftmp = idf3.dframe 

fetcher = FileContentFetcherMixin() 
detailz = ['fname', 'dclass','dcodez_short']
fundz_zrecordz = []
for i, fp in enumerate( fetcher.file_content( dftmp,vcolz=detailz) ): 
#     print( type(fp[0]), fp[0].data.shape)
    fp[0].remap_fundus_img()
    fundz_zrecordz.append(fp) 
print(len(fundz_zrecordz))
# _ = [print(type(r), type(r[0]), r[0].remapped_data[0].shape) for r in fundz_zrecordz]
# Out:
# 30

# %%
reshaped = fundz_zrecordz[0][0].remapped_data[0].shape
piper_procs = [
        ('fundusor', StareFundusTransformer()),
        ('force2d', Force2DTransformer()), ## flatten 
        ('rescaler', StandardScaler()),
        #('pca_dim', PCA(n_components=10) ), 
    ]
preproc_piper = Pipeline(piper_procs)
transformed_fmapz = preproc_piper.fit_transform( dftmp )
model_inputz = (np.array(transformed_fmapz).copy())
# _ = [print(type(fp)) for fp in transformed_fmapz]

transformed_fmapz = [fp.reshape( (*reshaped, -1)) for fp in transformed_fmapz]

# print( len( transformed_fmapz) )
# for i, fp in enumerate(transformed_fmapz):
#     print( f"{(i+1)}: { type(fp)}, {fp.shape}" )
# #     plot_funduz(fp[0])

# %%
def plot_funduz(lbl, fp, rfp):
    kk =  rfp[:,:,1:]
    _,_,nc = rfp.shape
    #print(rfp.shape, "==>", kk.shape)
      
    fname = f"{lbl}_fmap"
    print('working on ', fname)
    
    ## 1. before scaling et al 
    tx = ['origi', 'vessels', 'green', 'red', 'blue', 'combo']
    imgz = [fp.data, *fp.remapped_data]  
    ZUtilz.plot_images_list(imgz+[-im for im in imgz], 
                            titlez=tx, nc=len(imgz), cmap='gray',
                            save=fname, tdir=OUTPUTDIR)
    ## 2. with scaling et al 
    #print(rfp.shape)
    imgz = [kk,]+[rfp[:,:,c] for c in range(nc)]+[ rfp[:,:,:3]]    
    ZUtilz.plot_images_list(imgz+[-im for im in imgz], 
                            titlez=tx, nc=len(imgz), cmap='gray',
                            save=fname+"_rescaled", tdir=OUTPUTDIR )
    
for i, samp in enumerate( zip(fundz_zrecordz, transformed_fmapz) ):
    fp, rfp = samp
    print( f"{(i+1)}: {fp[1].label} === {type(fp[0])}:{fp[0].data.shape}, {type(rfp)}:{rfp.shape}" )
    plot_funduz( '_'.join(fp[1].data[:2]), fp[0], rfp)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1: im0176 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0176_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2: im0324 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0324_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 3: im0121 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0121_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 4: im0101 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0101_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 5: im0225 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0225_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 6: im0181 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0181_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 7: im0147 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0147_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 8: im0150 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0150_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 9: im0161 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0161_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 10: im0155 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0155_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 11: im0186 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0186_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 12: im0180 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0180_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 13: im0293 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0293_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 14: im0015 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0015_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 15: im0134 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0134_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 16: im0360 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0360_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 17: im0359 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0359_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 18: im0018 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0018_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 19: im0036 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0036_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 20: im0303 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0303_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 21: im0052 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0052_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 22: im0268 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0268_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 23: im0295 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0295_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 24: im0132 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0132_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 25: im0093 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0093_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 26: im0326 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0326_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 27: im0271 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0271_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 28: im0378 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0378_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 29: im0023 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0023_UNDEF_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 30: im0013 === <class '__main__.ZFundusImage'>:(151, 175, 3), <class 'numpy.ndarray'>:(151, 175, 4)
# working on  im0013_Sick_fmap
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
train_samples = len(dftmp)

n_train = int(0.80*train_samples)
print(n_train)

train_X, train_y = model_inputz[:(n_train+1)], dftmp['dclass_v'][:(n_train+1)]
test_X, test_y = model_inputz[(n_train+1):], dftmp['dclass_v'][(n_train+1):]
print( train_X.shape, train_y.shape)
print( test_X.shape, test_y.shape)

train_samples = len(train_X)
logit_m = LogisticRegression(C=50./train_samples, penalty='l1', 
                                   solver='saga', tol=0.00001, 
                                   multi_class='multinomial', 
                                   verbose=2, random_state=9)

plt.subplot(1,2,1)
train_y.value_counts().plot(kind='bar',stacked=False); 
plt.title('train set')
plt.subplot(1,2,2)
test_y.value_counts().plot(kind='bar',stacked=False); 
plt.title('test set'); 
plt.show();
# Out:
# 21
# (22, 105700) (22,)
# (8, 105700) (8,)

# %%
logit_m.fit(train_X, train_y)


sparsity = np.mean( logit_m.coef_ == 0) * 100 
score = logit_m.score(test_X, test_y)

print("Sparsity with L1 penalty: %.2f%%" % sparsity)
print("Test score with L1 penalty: %.4f" % score)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# max_iter reached after 5 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.4s finished
# LogisticRegression(C=2.272727272727273, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='multinomial', n_jobs=None,
#                    penalty='l1', random_state=9, solver='saga', tol=1e-05,
#                    verbose=2, warm_start=False)
# Sparsity with L1 penalty: 83.53%
# Test score with L1 penalty: 0.5000

# %%
COEF = logit_m.coef_.copy()
plt.figure(figsize=(10, 5))
scale = np.abs(COEF).max()
for i in range( NUM_CLASSES ):
    try:
        print('b4: ', COEF[i].shape , end=', ')
        cim = COEF[i].reshape((151, 175, -1))
        print('aft:', cim.shape )
        for c in [1,2,3]:
            ccm = 1/cim[:,:,c]*1 if c != 3 else cim[:,:,1:]/cim[:,:,:c]
            l1_plot = plt.subplot(3, 3, (i+1)+(3*(c-1)) ) 
            l1_plot.imshow(ccm, interpolation='nearest',
                           cmap=plt.cm.RdBu, vmin=-scale, vmax=scale) #
            l1_plot.set_xticks(())
            l1_plot.set_yticks(())
            l1_plot.set_xlabel( f'Class {CLASS_LABELZ[i]}' )
    except:
        pass

plt.suptitle(f"Classification vector for channel {['green','red-update', 'combo']}")

# run_time = time.time() - t0
# print('Example run in %.3f s' % run_time)

#d = datetime.now().strftime("%H%M%S")
plt.savefig( f'{OUTPUTDIR}/logit_res_{score}.png' , dpi=1200)
plt.show();
# Out:
# b4:  (105700,), aft: (151, 175, 4)

# %% [markdown]
# # TL with VGG, ResNet, Inception, MobileNet
#
# - https://machinelearningmastery.com/how-to-use-transfer-learning-when-developing-convolutional-neural-network-models/
# - https://keras.io/api/applications/

# %%
import keras
from keras.layers import Dense, Flatten, Input 
from keras.models import Model  

## --- TL typez
# from keras.applications.vgg16 import VGG16
# from keras.applications.inception_v3 import InceptionV3
# from keras.applications.resnet50 import ResNet50
# from keras.applications.mobilenet_v2 import MobileNetV2

## preprocessing according to imagenet etc @ TL
from keras.applications import vgg16 # import preprocess_input, decode_predictions
from keras.applications import inception_v3 
from keras.applications import resnet50  
from keras.applications import mobilenet_v2  
from keras.applications import densenet
from keras.applications import nasnet 




#TODO: send keras to torch 
import torch
# Out:
# Using TensorFlow backend.

# %%
#idf3.dframe.head(3)
def get_final_model_tl_as_is(tl_model, t_input_shape, n_classes ):
    # remove classifier/top and load with imagenet intialization
    # if no top then must define input_tensor arg 
    t_input = Input(shape=t_input_shape)
    # A model without a top will output activations of the last convolution or pooling layer directly
    # suo yi: add a global pooling layer e.g. max/avg to get a vector     
    model = tl_model(weights='imagenet', #default, None=retrain from scratch, 
                    include_top=False, 
                    input_tensor=t_input,
                    #input_shape=t_input_shape,
                    pooling='avg', #global pooling layer
                    classes=n_classes #resize last layer output classes 
                   )
    return model

def get_final_model_tl_as_extractor_preproc(n_inputs, n_classes, tl_model, act_func):
    tlm = tl_model()
    model = Model(inputs=tlm.inputs, outputs=tlm.layers[-2].output )    
    return model

def get_final_model_tl_as_extactor_in_another(n_inputs, n_classes, tl_model, act_func='relu'):
    tlm = tl_model(include_top=False, input_shape=n_inputs)
    flat = Flatten()(tlm.layers[-1].output)
    classes = Dense(1024, activation=act_func)(flat)
    output = Dense(n_classes, activation='softmax')(classes)
    
    # now combine and freeze weights 
    model = Model(inputs=tlm.inputs, outputs=output)
    for l in model.layers:
        l.trainable = False  #freeze weights 
    
    return model 

def train_model(model, data, epochs=3, 
                optimizer='rmsprop',
                loss='categorical_cross_entropy'):
    model.compile(optimzer=optimizer,  loss=loss)
    
    model.fit()
    
        
    
def reshape_img_to_tl(img, preprocessor, tsize):  
    img = skimage.transform.resize(img ,tsize, anti_aliasing=True)
    img = img.reshape((1,*img.shape))
    img = preprocessor(img)
    return img 
    
def predict(img, model, preprocessor, topn=3, tsize=(224,224)): ##remember to imagnet reshape  TODO: fix 1000 Vs sub  
    img = reshape_img_to_tl(img, preprocessor.preprocess_input, tsize)
    yhat = model.predict(img)
    ylbl = preprocessor.decode_predictions(yhat, top=topn)[0]
    return yhat, ylbl

# %%
sample_zrec = next(idf3.file_content)
sample_origin_img = sample_zrec[0].data
eg = skimage.transform.resize(sample_origin_img, (224,224), anti_aliasing=True)
sample_shape_classes = (sample_origin_img.shape, 3)
imgz = [sample_origin_img, eg]
tx = ['origi', 'resized']
ZUtilz.plot_images_list(imgz, titlez=tx, nc=len(imgz), cmap='gray',)

# %%
vggmodel = get_final_model_tl_as_is(vgg16.VGG16, *sample_shape_classes)
## TODO: predict (1,512 ) Vs (1,1000)
# Out:
# WARNING:tensorflow:From /home/moranis/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
argz = {'weights':'imagenet'} 



tsize = [(224, 224), (224, 224), (299, 299), (224, 224), 
         (224, 224), (224, 224), (331, 331)]
preprocz = [vgg16, resnet50, inception_v3, mobilenet_v2, 
            densenet, nasnet, nasnet]
modz = [vgg16.VGG16, resnet50.ResNet50, inception_v3.InceptionV3, mobilenet_v2.MobileNetV2, 
        densenet.DenseNet121, nasnet.NASNetMobile, nasnet.NASNetLarge,]
mlblz = ['vgg16', 'resnet50', 'inception_v3', 'mobilenet_v2',
         'densenet', 'nasnet-mobile', 'nasnet-large']
for i, mod in enumerate(modz):
    m = mod(**argz)
    lm = mlblz[i] #m.__class__
    predz, lblz = predict(sample_origin_img, m, preprocz[i], tsize=tsize[i])
    print(f"{i+1}. {lm}: {predz.shape}")  
    _ = [ print(f'\t{l}') for l in lblz ] 
    print("----" )
# Out:
# 1. vgg16: (1, 1000)
# 	('n03729826', 'matchstick', 0.075994894)
# 	('n01930112', 'nematode', 0.047881775)
# 	('n03666591', 'lighter', 0.030687852)
# ----
# 2. resnet50: (1, 1000)
# 	('n06359193', 'web_site', 0.06047109)
# 	('n01930112', 'nematode', 0.04534203)
# 	('n03196217', 'digital_clock', 0.036008336)
# ----
# 3. inception_v3: (1, 1000)
# 	('n01930112', 'nematode', 0.1292317)
# 	('n03729826', 'matchstick', 0.07664637)
# 	('n03196217', 'digital_clock', 0.039327875)
# ----
# 4. mobilenet_v2: (1, 1000)
# 	('n04286575', 'spotlight', 0.3039632)
# 	('n03729826', 'matchstick', 0.035763774)
# 	('n03196217', 'digital_clock', 0.034215204)
# ----
# 5. densenet: (1, 1000)
# 	('n03729826', 'matchstick', 0.14782709)
# 	('n04286575', 'spotlight', 0.05868089)
# 	('n01930112', 'nematode', 0.02615967)
# ----
# 6. nasnet-mobile: (1, 1000)
# 	('n03196217', 'digital_clock', 0.053690325)
# 	('n01930112', 'nematode', 0.052763678)
# 	('n03729826', 'matchstick', 0.021745147)
# ----
# 7. nasnet-large: (1, 1000)
# 	('n01930112', 'nematode', 0.112840086)
# 	('n03196217', 'digital_clock', 0.07052529)
# 	('n03729826', 'matchstick', 0.06315886)
# ----
